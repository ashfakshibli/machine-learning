# %% [markdown]
# ### Class 1
#
# #### Naive Bayes
# - Maximum Likelihood Probability of best fit to data
# - Maximum apiriori

# %% [markdown]
# ### Class 2

# %% [markdown]
# #### Parametric vs Non-Parametric Models
# ##### Parametric
# - Clear parameters. Like Logistic Regression. Optomal parameters
# -
#
# ##### Non Parametric [Naive Byaes]
# - Depends on the area of boundary selection

# %% [markdown]
# #### K-nearest neighbor classification
#
# - Samples with labels [Color classes like red & blue]
# - uncolored lables depends on K value.
# - Training examples are vectors. xi associated with a label yi
# - Instance based learning
# - lazy learning [just keeping the data]
# - use odd k to break ties
# - Distance between instancces
#     - Euclidean distance L1. diamond.
#     - Manhattan distance L2. circles.
#     - lp norm
#     - What is l inifity ? It forms a square
#     - lpower 1/2 = non convex
#     - l 0 is the center or undefined.
#     - l1, l2, l infinity makes the. distances closer to center. Most of the time l2 norm is used.
#     - KNN depends on K, more strongly depend on choice of metric of distance.
#     - Hamming distance/ Symbolic or categoricall variables [matching the agreements or disagreements]
# - Feature normalization. [more talks on PCA]
#
# - The decision boundary
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Voronoi Diagrams and Decision Bouundaries
#
# - Voronoi cell is Polyhedron [Polygon in 2D]
# - Check only the cell not all the points. Can break out early.
# - The curse of dimensionality [very high dimentional feature. vectors]
# - In super high dimensional space becomes 1
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### The Curse of Dimensionality
#
# - What fraction of points in a cube lie outside the sphere inscribed in it?
#  As the dimentionality increases, this fraction approaches.
# - Distances does not beahave same in higher dimensions. As d increases, this fraction goes to 1. In high diemnsions the sphere is far from center.
#
# How to deal?
# - dimensionality reduction technique, manifold learning
